# %%
import pandas as pd
import csv, json, math
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Upload data

# %%
dataKeys = ['cargoGeneroIdade', 'capacitacaoGeneroCargo', 'cargoTrans', 'salarioGeneroRaca', 'conAdmFormacaoGenero', 'educacaoGeneroIdade', 'jornadaGeneroRaca', 'conAdmIdadeGeneroRaca', 'permanenciaGeneroRaca', 'avaliacaoGeneroCargo', 'capacitacaoGeneroRaca', 'cargoGeneroDefic', 'maternidadeGeneroCargo', 'estadocivilGeneroCargo', 'jornadaGeneroCargo', 'cargoGeneroRaca', 'demissoesGeneroIdade', 'maternidadeGeneroRaca', 'vinculoGeneroRaca', 'motivosaidaGeneroCargo', 'avaliacaoGeneroRaca', 'estadocivilGeneroRaca', 'educacaoGeneroRaca', 'filhosGeneroCargo']

# %%
# %run panda.py
# Out:
# Processing company no. 0: AES Brasil (AES Tietê)
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# Processing company no. 1: Grupo Omnicom
# Processing company no. 2: AES Brasil (AES Eletropaulo)
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# Processing company no. 3: The Coca-Cola Company
# Processing company no. 4: AES Brasil (AES Ergos)
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# Processing company no. 5: BP
# Processing company no. 6: Carrefour Brasil
# Processing company no. 7: Grupo BASF
# Processing company no. 8: Zurich Santander Brasil Seg e Prev S/A
# Processing company no. 9: Mattos Filho, Veiga Filho, Marrey Jr e Quiroga Advogados
# Processing company no. 10: SABIN
# Processing company no. 11: Avon Products Inc
# Processing company no. 12: IBM IND DE MAQUINAS E SERVICOS LTDA
# Processing company no. 13: FUNDAÇÃO ANTONIO PRUDENTE
# Processing company no. 14: Beleza Natural
# Processing company no. 15: Grupo Santander
# Processing company no. 16: DIAGEO
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# <class 'str'> Todos- menos estagiários
# Processing company no. 17: Magazine Luiza
# Processing company no. 18: Grupo Boticário
# Processing company no. 19: IVIA
# Processing company no. 20: Anheuser-Busch InBev
# Processing company no. 21: Brookfield
# Processing company no. 22: Bayer
# Processing company no. 23: Klar Construtora
# Processing company no. 24: Beleza Natural
# Processing company no. 25: Grupo Telefónica
# Processing company no. 26: NT
# Processing company no. 27: TECNOFARMA SA
# Processing company no. 28: Accenture
# Processing company no. 29: GRUPO ANGÁ
# Processing company no. 30: Não pertence
# Processing company no. 31: Praxair
# Processing company no. 32: Kroll
# Processing company no. 33: Allianz SE
# Processing company no. 34: Banco BTG Pactual S.A.
# Processing company no. 35: Automated Precision Incorporation
# Processing company no. 36: Kimberly-Clark
# Processing company no. 37: nt
# Processing company no. 38: KIRIN HOLDING
# Processing company no. 39: MUSIC2
# Processing company no. 40: Citi
# Processing company no. 41: Loreal
# Processing company no. 42: Royal Dutch Shell
# Processing company no. 43: Reckitt Benckiser
# Processing company no. 44:  -
# Processing company no. 45: GE
# Processing company no. 46: NT
# Processing company no. 47: Alelo
# Processing company no. 48: NT
# Processing company no. 49: Itau Unibanco Holding SA
# Processing company no. 50: Johnson & Johnson do Brasil Industria e Comércio de Produtos para a Saúde Ltda
# Processing company no. 51: Novartis Biociências
# Processing company no. 52: PwC
# Processing company no. 53: Zurich Insurance Group
# Processing company no. 54: ClearSale S.A.
# Processing company no. 55: Tauá Resort Caeté Ltda
# Processing company no. 56: TozziniFreire Advogados
# Processing company no. 57: Edenred
# Processing company no. 58: SAP SE
# Processing company no. 59: Tércio Wanderley
# Processing company no. 60: Unimed Volta Redonda Cooperativa de Trabalho Médico
# Processing company no. 61: NT
# Processing company no. 62: Martinez&Calvo Palestras, Treinamentos e Finanças
# Processing company no. 63: Gannett Company
# Processing company no. 64: NT
# Processing company no. 65: EY
# Processing company no. 66: NT
# Processing company no. 67: Ale Combustíveis
# Processing company no. 68: Saudalys Franchising
# Processing company no. 69: PepsiCo
# Processing company no. 70: Promon
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# <class 'str'> 100%
# Processing company no. 71: NT
# Processing company no. 72: Atento
# Processing company no. 73: GENERAL MOTORS
# Processing company no. 74: Arenales Homeopatianimal
# Processing company no. 75: MetLife
# Processing company no. 76: Rede Ímpar
# Processing company no. 77: BELAGRÍCOLA
# Processing company no. 78: Arcos Dourados Comércio de Alimentos Ltda
# Processing company no. 79: Pfizer
# Processing company no. 80: MULTIPLUS
# Processing company no. 81: UNIMED-RIO
# Processing company no. 82: LafargeHolcim
# Processing company no. 83: Construtora Mendonça Aguiar
# Processing company no. 84: FALCONI CONSULTORES DE RESULTADO
# Processing company no. 85: Schneider Electric
# Processing company no. 86: Takeda Farmacêutica do Brasil
# Processing company no. 87: MPD Engenharia
# Processing company no. 88: ArcelorMittal
# ('', 0)

# %%
cleanKeys = ['cargoGeneroIdade', 'capacitacaoGeneroCargo', 'cargoTrans', 'conAdmFormacaoGenero', 'educacaoGeneroIdade', 'jornadaGeneroRaca', 'conAdmIdadeGeneroRaca', 'permanenciaGeneroRaca', 'capacitacaoGeneroRaca', 'cargoGeneroDefic', 'maternidadeGeneroCargo', 'estadocivilGeneroCargo', 'jornadaGeneroCargo', 'cargoGeneroRaca', 'demissoesGeneroIdade', 'maternidadeGeneroRaca', 'vinculoGeneroRaca', 'motivosaidaGeneroCargo', 'estadocivilGeneroRaca', 'educacaoGeneroRaca', 'filhosGeneroCargo']

# %%
def getDemo(demo, field):
    clusteredData = pd.DataFrame(columns=['specifics','company','variable','value'])
    for empresai in demo:
        aux = pd.DataFrame.copy(empresai[field])
        aux['specifics'] = aux.index
        aux['company'] = empresai['nomeDaEmpresa'][1]
        clusteredData= pd.concat((clusteredData,aux.melt(id_vars=['specifics','company'])),axis=0)
    return clusteredData[clusteredData['value'].isnull() == False]

def transformInProportion

# %%
trans = getDemo(demoData,dataKeys[8])
sns.stripplot(y='variable', x="value", hue="specifics",
              data=trans, dodge=True, jitter=True,
              alpha=.9, zorder=1)

# %%
trans = getDemo(demoData,dataKeys[11])
sns.stripplot(y='variable', x="value", hue="specifics",
              data=trans, dodge=True, jitter=True,
              alpha=.9, zorder=1)

# %%
trans = getDemo(demoData,dataKeys[15])
sns.stripplot(y='variable', x="value", hue="specifics",
              data=trans, dodge=True, jitter=True,
              alpha=.9, zorder=1)
